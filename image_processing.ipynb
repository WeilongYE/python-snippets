# %% [markdown]
# <a href="https://colab.research.google.com/github/WeilongYE/python-snippets/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Open an url Image by PIL

# %%
from PIL import Image
import requests
from io import BytesIO

url = "https://via.placeholder.com/300"
response = requests.get(url)
response.raise_for_status()

img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ## Open an url image by TensorFlow

# %%
import tensorflow as tf
import requests
import matplotlib.pyplot as plt

url = "https://via.placeholder.com/300"
response = requests.get(url)
response.raise_for_status()

# image = tf.io.read_file(path)
image = tf.image.decode_image(response.content, 3)
image_array = image.numpy().astype("uint8")
plt.imshow(image_array)
plt.axis("off")  # Hide axis for better visualization
plt.title("Example")
plt.show()
